# %% [markdown]
# <a href="https://colab.research.google.com/github/ErickAPB2412/Trabajo-SQP/blob/main/Pregunta_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyscopus==1.0.3a2

# %%
from pyscopus import Scopus
import numpy
import pandas as pd # Use pd as an alias for pandas
import requests

# %%
key = "35c766943159fbae115b7b54eb74217d"
scopus = Scopus(key)

# %%
s = input("Ingresa tus palabras de búsqueda: ")
search_df = scopus.search(s, count=200,view='STANDARD')
# Out:
# Ingresa tus palabras de búsqueda: TITLE-ABS-KEY((("fundamentals of microscopy") AND ("microscopy") AND ("microscopy")))

# %%
from IPython.display import display
display(search_df)
# Out:
#      scopus_id                           title  \
# 0  85147092444         Multi-Photon Microscopy
# 1  85148398059      Fundamentals of Microscopy
# 2  85086008607      Fundamentals of Microscopy
# 3  85122909019   An introduction to microscopy
# 4  77953541822      Fundamentals of Microscopy
# 5  84920087523  The fundamentals of microscopy
#
#                               publication_name  issn  \
# 0                            Current Protocols  None
# 1  Microscope Image Processing, Second Edition  None
# 2           Current protocols in mouse biology  None
# 3                An Introduction to Microscopy  None
# 4                  Microscope Image Processing  None
# 5      The Principles of Clinical Cytogenetics  None
#
#                                                 isbn     eissn volume  \
# 0                                               None  26911299      3
# 1  [{'@_fa': 'true', '$': '[9780128210499, 978012...      None   None
# ...
