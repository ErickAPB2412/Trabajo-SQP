# %% [markdown]
# <a href="https://colab.research.google.com/github/ErickAPB2412/Trabajo-SQP/blob/main/Pregunta_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyscopus==1.0.3a2
# Out:
# Collecting pyscopus==1.0.3a2
#   Downloading pyscopus-1.0.3a2-py3-none-any.whl.metadata (2.5 kB)
# Downloading pyscopus-1.0.3a2-py3-none-any.whl (11 kB)
# Installing collected packages: pyscopus
# Successfully installed pyscopus-1.0.3a2

# %%
from pyscopus import Scopus
import numpy
import pandas as pd # Use pd as an alias for pandas
import requests

# %%
key = "bf9b190c7b5a80bf62701919c74f2d37"
scopus = Scopus(key)

# %%
s = input("Ingresa tus palabras de búsqueda: ")
search_df = scopus.search(s, count=200,view='STANDARD')
# Out:
# Ingresa tus palabras de búsqueda: TITLE-ABS-KEY((("molecularly imprinted polymers for drugs") AND ("molecularly imprinted polymers for drugs") AND ("molecularly imprinted polymers for drugs" AND "drugs ")))

# %%
from IPython.display import display
display(search_df)
# Out:
#      scopus_id                                              title  \
# 0  85152174684  A human VEGF magnetic molecularly imprinted po...
# 1  85142851886  In Vivo Applications of Molecularly Imprinted ...
# 2  85162095201  Molecularly imprinted polymers for drug delive...
# 3  85042740657  Electrochemical methods based on molecularly i...
# 4  85013676216  Recent configurations and progressive uses of ...
# 5  42149135444  Stimuli-responsive molecularly imprinted polym...
# 6  33751011600  Supercritical fluid polymerisation and impregn...
# 7   1842766315   Molecularly imprinted polymers for drug delivery
# 8   2442421099  Molecularly imprinted polymers as antibody and...
# 9   0043268099  LC packing materials for pharmaceutical and bi...
#
#                                     publication_name      issn  \
# 0                            Chemical Communications  13597345
# 1        International Journal of Molecular Sciences  16616596
# 2  Smart Polymeric Nano-Constructs in Drug Delive...      None
# 3   International Journal of Electrochemical Science      None
# 4                                            Talanta  00399140
# 5                              Current Drug Delivery  15672018
# 6                    Journal of Supercritical Fluids  08968446
# 7  Journal of Chromatography B: Analytical Techno...  15700232
# 8             Analytical and Bioanalytical Chemistry  16182642
# 9  Se pu = Chinese journal of chromatography / Zh...  10008713
#
#                                                 isbn     eissn volume  \
# 0                                               None  1364548X     59
# 1                                               None  14220067     23
# 2  [{'@_fa': 'true', '$': '[9780323912488, 978032...      None   None
# 3                                               None  14523981     13
# 4                                               None      None    167
# 5                                               None      None      5
# 6                                               None      None     39
# 7                                               None      None    804
# 8                                               None      None    378
# 9                                               None      None     20
#
#   page_range  cover_date                                 doi  citation_count  \
# 0  4229-4232  2023-03-14                  10.1039/d3cc00088e               2
# 1       None  2022-11-01               10.3390/ijms232214071              18
# 2    249-287  2022-01-01  10.1016/B978-0-323-91248-8.00016-7               2
# 3  2556-2576  2018-03-01                 10.20964/2018.03.75              99
# 4    470-485  2017-05-15       10.1016/j.talanta.2017.02.049             128
# 5      85-96  2008-04-01          10.2174/156720108783954888             114
# 6    102-106  2006-11-01        10.1016/j.supflu.2006.01.013              81
# 7    231-245  2004-05-05       10.1016/j.jchromb.2003.12.032             353
# 8  1887-1897  2004-04-01           10.1007/s00216-003-2450-8             303
# 9    508-518  2002-01-01                                None               0
#
#                                          affiliation aggregation_type  \
# 0  [{'name': 'Southwest Jiaotong University', 'ci...          Journal
# 1  [{'name': 'Universitatea de Medicina si Farmac...          Journal
# 2  [{'name': 'I.S.F. College of Pharmacy', 'city'...             Book
# 3  [{'name': 'Universitatea de Medicina si Farmac...          Journal
# 4  [{'name': 'Islamic Azad University, Saveh Bran...          Journal
# 5  [{'name': 'Università della Calabria', 'city':...          Journal
# 6  [{'name': 'Instituto de Tecnologia Química e B...          Journal
# 7  [{'name': 'Universidad de Santiago de Composte...          Journal
# 8  [{'name': 'Lunds Universitet', 'city': 'Lund',...          Journal
# 9  [{'name': 'Mukogawa Women's University', 'city...          Journal
#
#   subtype_description authors  \
# 0             Article      []
# 1              Review      []
# 2        Book Chapter      []
# 3              Review      []
# 4              Review      []
# 5              Review      []
# 6             Article      []
# 7              Review      []
# 8              Review      []
# 9              Review      []
#
#                                            full_text
# 0  https://api.elsevier.com/content/article/eid/1...
# 1                                               None
# 2  https://api.elsevier.com/content/article/eid/3...
# 3                                               None
# 4  https://api.elsevier.com/content/article/eid/1...
# 5                                               None
# 6  https://api.elsevier.com/content/article/eid/1...
# 7  https://api.elsevier.com/content/article/eid/1...
# 8                                               None
# 9                                               None
