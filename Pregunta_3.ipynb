# %% [markdown]
# <a href="https://colab.research.google.com/github/ErickAPB2412/Trabajo-SQP/blob/main/Pregunta_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install -U "transformers==4.40.0" --upgrade
# !pip install -i https://pypi.org/simple/ bitsandbytes
# !pip install accelerate

# %%
#@title Cargando LLAMA3
import transformers
import torch

model_id = "unsloth/llama-3-8b-Instruct-bnb-4bit"

pipeline = transformers.pipeline(
    "text-generation",
    model=model_id,
    model_kwargs={
        "torch_dtype": torch.float16,
        "quantization_config": {"load_in_4bit": True},
        "low_cpu_mem_usage": True,
    },
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.26k [00:00<?, ?B/s]
# ...

# %%
# Lista en Python con preguntas dirigidas al abstract
preguntas_abstract = [
    "¿Cómo contribuye este estudio al conocimiento existente sobre la síntesis de MIP?",
    "¿Qué variables clave se consideraron durante el proceso de síntesis?",
    "¿Cómo se validó la efectividad de los MIP sintetizados para su aplicación en fármacos?"
]

# Imprimir la lista
for pregunta in preguntas_abstract:
    print(pregunta)
# Out:
# ¿Cómo contribuye este estudio al conocimiento existente sobre la síntesis de MIP?
# ¿Qué variables clave se consideraron durante el proceso de síntesis?
# ¿Cómo se validó la efectividad de los MIP sintetizados para su aplicación en fármacos?

# %%
import pandas as pd

# %%
mitabla = pd.read_csv("scopus.csv")
mitabla.head(12)
# Out:
#                                               Authors  \
# 0           Zheng L.; Wu J.; Wang J.; Wu Y.; Huang X.
# 1   Janjhi F.A.; Chandio I.; Janwery D.; Vatanpour...
# 2   Khan I.; Rizwan Tariq M.; Ahmad M.; Khan I.; Z...
# 3          Faheem M.; Azher Hassan M.; Du J.; Wang B.
# 4        Yang S.; Wu Y.; Bi S.; Xu X.; Wu W.; Wang Y.
# 5   Liu S.; Hui J.; Li H.; Li Y.; He X.; Chen L.; ...
# 6   Gong H.; Li S.; Cheng Y.; Chen F.; Chen C.; Ca...
# 7   Tang H.; He L.; Zhou Z.; Cheng W.; Liu Z.; Yan...
# 8   Liu S.; Li J.; Hu Z.; Zhang X.; Feng R.; Wang ...
# 9   Chang R.; Wang H.; Liu S.; Dong Y.; Zhang G.; ...
# 10  Xie D.; Kuang Y.; Yuan B.; Zhang Y.; Ye C.; Gu...
# 11               Pimalai D.; Putnin T.; Bamrungsap S.
#
#                                     Author full names  \
# 0   Zheng, Lingxin (57432087100); Wu, Jiangyi (572...
# 1   Janjhi, Farooque Ahmed (57220043908); Chandio,...
# 2   Khan, Idrees (56124113300); Rizwan Tariq, Muha...
# ...

# %%
def consultas(input):
  messages = [
    {"role"   : "system",
     "content": context1},
    {"role"   : "user",
     "content": "Eres un especialista en sintesis de plimeros molecularmente impresos para farmacos: ¿Cuál es el principal descubrimiento o aporte de este artículo en su área de investigación?"},
  ]

  prompt = pipeline.tokenizer.apply_chat_template(
          messages,
          tokenize=False,
          add_generation_prompt=True
  )

  terminators = [
      pipeline.tokenizer.eos_token_id,
      pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
  ]

  outputs = pipeline(
      prompt,
      max_new_tokens=256,
      eos_token_id=terminators,
      do_sample=True,
      temperature=0.6,
      top_p=0.9,
  )

  return outputs[0]["generated_text"][len(prompt):]

# %%
mitabla['Analisis1'] = None # Changed df to mitabla

for i in range(12):
  context1 = mitabla["Abstract"][i] # Changed df to mitabla
  response = consultas(context1)
  mitabla['Analisis1'][i] = response # Changed df to mitabla
# Out:
# <ipython-input-14-6149879d0404>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mitabla['Analisis1'][i] = response # Changed df to mitabla
# <ipython-input-14-6149879d0404>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mitabla['Analisis1'][i] = response # Changed df to mitabla
# <ipython-input-14-6149879d0404>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
mitabla  # Changed df to mitabla
# Out:
#                                               Authors  \
# 0           Zheng L.; Wu J.; Wang J.; Wu Y.; Huang X.
# 1   Janjhi F.A.; Chandio I.; Janwery D.; Vatanpour...
# 2   Khan I.; Rizwan Tariq M.; Ahmad M.; Khan I.; Z...
# 3          Faheem M.; Azher Hassan M.; Du J.; Wang B.
# 4        Yang S.; Wu Y.; Bi S.; Xu X.; Wu W.; Wang Y.
# 5   Liu S.; Hui J.; Li H.; Li Y.; He X.; Chen L.; ...
# 6   Gong H.; Li S.; Cheng Y.; Chen F.; Chen C.; Ca...
# 7   Tang H.; He L.; Zhou Z.; Cheng W.; Liu Z.; Yan...
# 8   Liu S.; Li J.; Hu Z.; Zhang X.; Feng R.; Wang ...
# 9   Chang R.; Wang H.; Liu S.; Dong Y.; Zhang G.; ...
# 10  Xie D.; Kuang Y.; Yuan B.; Zhang Y.; Ye C.; Gu...
# 11               Pimalai D.; Putnin T.; Bamrungsap S.
#
#                                     Author full names  \
# 0   Zheng, Lingxin (57432087100); Wu, Jiangyi (572...
# 1   Janjhi, Farooque Ahmed (57220043908); Chandio,...
# 2   Khan, Idrees (56124113300); Rizwan Tariq, Muha...
# ...

# %%
mitabla["Analisis1"][0]  # Changed df to mitabla
# Out:
# "What a great question!\n\nAs a molecularly imprinted polymer (MIP) expert for pharmaceutical applications, I'd like to highlight the main discovery or contribution of this article in my area of research:\n\n1. **Dual-functional monomers**: The authors have successfully developed a novel approach by combining two ionic liquids, 1-allyl-3-methylimidazoliumbis[(trifluoromethy)sulfonyl]imide and N,N,N-trimethyl-1-(4-vinylphenyl)methanaminium chloride, as dual functional monomers. This is a significant advancement in MIP synthesis, as it allows for the creation of a molecularly imprinted monolith-based microelectrode (MBM) with enhanced recognition capabilities.\n2. **In-situ fabrication of MBM**: The authors have demonstrated the in-situ fabrication of MBM, which is a crucial step in MIP synthesis. This approach eliminates the need for laborious and time-consuming polymerization processes, making it more efficient and cost-effective.\n3. **Electroenhanced solid-phase microextraction (EE
# ...

# %%
mitabla["Analisis1"][1]  # Changed df to mitabla
# Out:
# 'Como especialista en síntesis de polímeros molecularmente impresos (MIP) para farmacos, me parece interesante ver cómo este estudio sobre electrospun nanofibrous membranes (ENMs) puede contribuir al conocimiento existente sobre la síntesis de MIP.\n\nAunque el estudio no se enfoca directamente en la síntesis de MIP, puedo identificar algunas conexiones indirectas que pueden ser relevantes:\n\n1. Avances en la síntesis de materiales: El estudio sobre ENMs puede contribuir a la comprensión de cómo se pueden diseñar y sintetizar materiales con propiedades específicas, como la porosidad y la superficie. Estos avances pueden ser aplicados a la síntesis de MIP, permitiendo la creación de materiales con propiedades más controladas y específicas.\n2. Manipulación de la superficie: El estudio sobre ENMs destaca la importancia de la superficie en la función de los materiales. En la síntesis de MIP, la superficie también es crucial, ya que se utiliza para reconocer y capturar moléculas específ
# ...

# %%
mitabla["Analisis1"][2]  # Changed df to mitabla
# Out:
# 'Aunque el estudio en cuestión no se enfoca directamente en la síntesis de MIP (materiales impresos molecularmente), puedo identificar algunas contribuciones indirectas y relacionadas con la síntesis de MIP que se pueden extraer de este trabajo.\n\n1. **Heteroestructuras**: El estudio muestra la creación de heteroestructuras compuestas por ZnO y WO3, lo que es similar a la creación de heteroestructuras en la síntesis de MIP. La formación de interfaces entre materiales con propiedades electrónicas diferentes puede ser beneficiosa para la síntesis de MIP, ya que permite la creación de sitios de reconocimiento molecular más efectivos.\n2. **Control de la morfología**: El estudio demuestra que la adición de Hexamethylenetetramine (HMTA) es crucial para la formación de la estructura deseada. En la síntesis de MIP, el control de la morfología y la superficie es fundamental para la creación de sitios de reconocimiento molecular efectivos. La comprensión de cómo controlar la morfología y la 
# ...

# %%
def consultas(input):
  messages = [
    {"role"   : "system",
     "content": context1},
    {"role"   : "user",
     "content": "Eres un especialista en sintesis de plimeros molecularmente impresos para farmacos: ¿Qué variables clave se consideraron durante el proceso de síntesis?"},
  ]

  prompt = pipeline.tokenizer.apply_chat_template(
          messages,
          tokenize=False,
          add_generation_prompt=True
  )

  terminators = [
      pipeline.tokenizer.eos_token_id,
      pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
  ]

  outputs = pipeline(
      prompt,
      max_new_tokens=256,
      eos_token_id=terminators,
      do_sample=True,
      temperature=0.6,
      top_p=0.9,
  )

  return outputs[0]["generated_text"][len(prompt):]

# %%
mitabla['Analisis2'] = None # Changed df to mitabla

for i in range(12):
  context1 = mitabla["Abstract"][i] # Changed df to mitabla
  response = consultas(context1)
  mitabla['Analisis2'][i] = response # Changed df to mitabla
# Out:
# <ipython-input-19-53a4ad841ce1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mitabla['Analisis2'][i] = response # Changed df to mitabla
# <ipython-input-19-53a4ad841ce1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mitabla['Analisis2'][i] = response # Changed df to mitabla
# <ipython-input-19-53a4ad841ce1>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
mitabla  # Changed df to mitabla
# Out:
#                                               Authors  \
# 0           Zheng L.; Wu J.; Wang J.; Wu Y.; Huang X.
# 1   Janjhi F.A.; Chandio I.; Janwery D.; Vatanpour...
# 2   Khan I.; Rizwan Tariq M.; Ahmad M.; Khan I.; Z...
# 3          Faheem M.; Azher Hassan M.; Du J.; Wang B.
# 4        Yang S.; Wu Y.; Bi S.; Xu X.; Wu W.; Wang Y.
# 5   Liu S.; Hui J.; Li H.; Li Y.; He X.; Chen L.; ...
# 6   Gong H.; Li S.; Cheng Y.; Chen F.; Chen C.; Ca...
# 7   Tang H.; He L.; Zhou Z.; Cheng W.; Liu Z.; Yan...
# 8   Liu S.; Li J.; Hu Z.; Zhang X.; Feng R.; Wang ...
# 9   Chang R.; Wang H.; Liu S.; Dong Y.; Zhang G.; ...
# 10  Xie D.; Kuang Y.; Yuan B.; Zhang Y.; Ye C.; Gu...
# 11               Pimalai D.; Putnin T.; Bamrungsap S.
#
#                                     Author full names  \
# 0   Zheng, Lingxin (57432087100); Wu, Jiangyi (572...
# 1   Janjhi, Farooque Ahmed (57220043908); Chandio,...
# 2   Khan, Idrees (56124113300); Rizwan Tariq, Muha...
# ...

# %%
mitabla["Analisis2"][0]  # Changed df to mitabla
# Out:
# "What a fascinating topic!\n\nAs a molecularly imprinted polymer (MIP) expert, I'd be delighted to walk you through the key variables considered during the synthesis process. In the study you mentioned, the researchers aimed to develop a MIP-based microelectrode (MBM) for the selective isolation and extraction of phenolic acids (PAs). Here are the crucial variables they likely considered:\n\n1. **Template molecule**: The choice of template molecule is critical. In this case, vanillic acid (VA) was used as the template, which is a common phenolic acid found in various plant-based products.\n2. **Monomer selection**: The selection of monomers is essential for creating a MIP with specific recognition properties. The researchers chose a combination of ionic liquids (ILs), including 1-allyl-3-methylimidazoliumbis[(trifluoromethy)sulfonyl]imide and N,N,N-trimethyl-1-(4-vinylphenyl)methanaminium chloride, as dual functional monomers. These ILs were designed to provide both recognition and e
# ...

# %%
mitabla["Analisis2"][1]  # Changed df to mitabla
# Out:
# 'Como especialista en síntesis de polímeros molecularmente impresos para fármacos, puedo decir que consideramos varias variables clave durante el proceso de síntesis. A continuación, te presento algunas de las más importantes:\n\n1. **Monómero**: El monómero es el bloque fundamental de la síntesis del polímero. Es importante seleccionar un monómero que tenga las propiedades deseadas para el fármaco, como la actividad biológica, la biodisponibilidad y la toxicidad.\n2. **Conjugación**: La conjugación es el proceso de unión de los monómeros para formar un polímero. Hay varios tipos de conjugación, como la conjugación estérica, la conjugación química y la conjugación bioquímica. Cada tipo de conjugación puede influir en la estructura y la función del polímero.\n3. **Longitud del polímero**: La longitud del polímero puede afectar su biodisponibilidad, su actividad biológica y su toxicidad. La síntesis de polímeros con longitudes específicas puede ser importante'

# %%
def consultas(input):
  messages = [
    {"role"   : "system",
     "content": context1},
    {"role"   : "user",
     "content": "Eres un especialista en sintesis de plimeros molecularmente impresos para farmacos: ¿Cómo se validó la efectividad de los MIP sintetizados para su aplicación en fármacos?"},
  ]

  prompt = pipeline.tokenizer.apply_chat_template(
          messages,
          tokenize=False,
          add_generation_prompt=True
  )

  terminators = [
      pipeline.tokenizer.eos_token_id,
      pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
  ]

  outputs = pipeline(
      prompt,
      max_new_tokens=256,
      eos_token_id=terminators,
      do_sample=True,
      temperature=0.6,
      top_p=0.9,
  )

  return outputs[0]["generated_text"][len(prompt):]

# %%
mitabla['Analisis3'] = None # Changed df to mitabla

for i in range(12):
  context1 = mitabla["Abstract"][i] # Changed df to mitabla
  response = consultas(context1)
  mitabla['Analisis3'][i] = response # Changed df to mitabla
# Out:
# <ipython-input-24-9498b20dfca7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mitabla['Analisis3'][i] = response # Changed df to mitabla
# <ipython-input-24-9498b20dfca7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mitabla['Analisis3'][i] = response # Changed df to mitabla
# <ipython-input-24-9498b20dfca7>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
mitabla  # Changed df to mitabla
# Out:
#                                               Authors  \
# 0           Zheng L.; Wu J.; Wang J.; Wu Y.; Huang X.
# 1   Janjhi F.A.; Chandio I.; Janwery D.; Vatanpour...
# 2   Khan I.; Rizwan Tariq M.; Ahmad M.; Khan I.; Z...
# 3          Faheem M.; Azher Hassan M.; Du J.; Wang B.
# 4        Yang S.; Wu Y.; Bi S.; Xu X.; Wu W.; Wang Y.
# 5   Liu S.; Hui J.; Li H.; Li Y.; He X.; Chen L.; ...
# 6   Gong H.; Li S.; Cheng Y.; Chen F.; Chen C.; Ca...
# 7   Tang H.; He L.; Zhou Z.; Cheng W.; Liu Z.; Yan...
# 8   Liu S.; Li J.; Hu Z.; Zhang X.; Feng R.; Wang ...
# 9   Chang R.; Wang H.; Liu S.; Dong Y.; Zhang G.; ...
# 10  Xie D.; Kuang Y.; Yuan B.; Zhang Y.; Ye C.; Gu...
# 11               Pimalai D.; Putnin T.; Bamrungsap S.
#
#                                     Author full names  \
# 0   Zheng, Lingxin (57432087100); Wu, Jiangyi (572...
# 1   Janjhi, Farooque Ahmed (57220043908); Chandio,...
# 2   Khan, Idrees (56124113300); Rizwan Tariq, Muha...
# ...

# %%
mitabla["Analisis3"][0]  # Changed df to mitabla
# Out:
# "As a molecularly imprinted polymer (MIP) expert, I'd be happy to walk you through the validation process for the MIPs synthesized for pharmaceutical applications.\n\nValidation of MIPs involves a series of experiments to demonstrate their effectiveness, selectivity, and stability for their intended application. Here are the general steps:\n\n1. **Template recognition**: The first step is to verify that the MIP recognizes the target molecule (template) with high affinity. This is typically done using techniques like UV-vis spectroscopy, fluorescence spectroscopy, or chromatography (e.g., HPLC, GC).\n2. **Binding studies**: The next step is to investigate the binding properties of the MIP, including the binding capacity, binding constant (Kd), and selectivity. This is often done using techniques like equilibrium dialysis, frontal analysis, or competitive binding assays.\n3. **Binding specificity**: To validate the MIP's specificity, experiments are performed to assess its binding to s
# ...

# %%
mitabla["Analisis3"][1]  # Changed df to mitabla
# Out:
# "As a specialist in molecularly imprinted polymer (MIP) synthesis for pharmaceuticals, I can walk you through the typical validation process for assessing the effectiveness of MIPs synthesized for pharmaceutical applications.\n\nValidation of MIP effectiveness involves a multi-step process that ensures the MIPs meet the required standards for pharmaceutical applications. Here's a general outline of the steps involved:\n\n1. **MIP synthesis and characterization**: The MIP is synthesized using a specific monomer, cross-linker, and template molecule. The resulting MIP is then characterized using techniques such as Fourier Transform Infrared (FTIR), Nuclear Magnetic Resonance (NMR), and Scanning Electron Microscopy (SEM) to assess its molecular structure, surface morphology, and polymer chain architecture.\n2. **Template molecule binding studies**: The MIP is evaluated for its ability to bind to the template molecule using techniques such as equilibrium dialysis, spectroscopy (e.g., UV-V
# ...

# %%
def puntuacion(input):
  messages = [
    {"role"   : "system",
     "content": context1},
    {"role"   : "user",
     "content": "Eres un especialista en sintesis de plimeros molecularmente impresos para farmacos:,puntúa del 1 al 5, donde 1 es lo peor y 5 es lo mejor, imprime solamente el número o puntuacion de: ¿qué aporte tuvo sintesis de polimeros molecularmente imrpesos para farmacos: "},
  ]

  prompt = pipeline.tokenizer.apply_chat_template(
          messages,
          tokenize=False,
          add_generation_prompt=True
  )

  terminators = [
      pipeline.tokenizer.eos_token_id,
      pipeline.tokenizer.convert_tokens_to_ids("<|eot_id|>")
  ]

  outputs = pipeline(
      prompt,
      max_new_tokens=256,
      eos_token_id=terminators,
      do_sample=True,
      temperature=0.6,
      top_p=0.9,
  )

  return outputs[0]["generated_text"][len(prompt):]

# %%
mitabla['Score_1'] = None # Changed df to mitabla

for i in range(12):
  context1 = mitabla["Abstract"][i] # Changed 'Topic' to 'Abstract' assuming that is the correct column
  response = puntuacion(context1)
  mitabla['Score_1'][i] = response
# Out:
# <ipython-input-29-96c03f2862b2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mitabla['Score_1'][i] = response
# <ipython-input-29-96c03f2862b2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mitabla['Score_1'][i] = response
# <ipython-input-29-96c03f2862b2>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mitabla['Score_1'][i] = response
# <ipython-input-29-96c03f2862b2>:6: SettingWithCopyWarning:
# ...

# %%
mitabla
# Out:
#                                               Authors  \
# 0           Zheng L.; Wu J.; Wang J.; Wu Y.; Huang X.
# 1   Janjhi F.A.; Chandio I.; Janwery D.; Vatanpour...
# 2   Khan I.; Rizwan Tariq M.; Ahmad M.; Khan I.; Z...
# 3          Faheem M.; Azher Hassan M.; Du J.; Wang B.
# 4        Yang S.; Wu Y.; Bi S.; Xu X.; Wu W.; Wang Y.
# 5   Liu S.; Hui J.; Li H.; Li Y.; He X.; Chen L.; ...
# 6   Gong H.; Li S.; Cheng Y.; Chen F.; Chen C.; Ca...
# 7   Tang H.; He L.; Zhou Z.; Cheng W.; Liu Z.; Yan...
# 8   Liu S.; Li J.; Hu Z.; Zhang X.; Feng R.; Wang ...
# 9   Chang R.; Wang H.; Liu S.; Dong Y.; Zhang G.; ...
# 10  Xie D.; Kuang Y.; Yuan B.; Zhang Y.; Ye C.; Gu...
# 11               Pimalai D.; Putnin T.; Bamrungsap S.
#
#                                     Author full names  \
# 0   Zheng, Lingxin (57432087100); Wu, Jiangyi (572...
# 1   Janjhi, Farooque Ahmed (57220043908); Chandio,...
# 2   Khan, Idrees (56124113300); Rizwan Tariq, Muha...
# ...

# %%
# Guardar el DataFrame inicial como CSV
mitabla.to_csv('df_inicial.csv', index=False) # Changed 'df_inicial' to 'mitabla'

# Guardar el DataFrame final como CSV
mitabla.to_csv('df_final.csv', index=False) # Changed 'df_final' to 'mitabla'

# %%
from google.colab import files

# Descargar el archivo CSV del DataFrame inicial
files.download('df_inicial.csv')

# Descargar el archivo CSV del DataFrame final
files.download('df_final.csv')
